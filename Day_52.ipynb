# %% [markdown]
# <a href="https://colab.research.google.com/github/Rakshitha149/Python_Basics/blob/main/Day_52.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Coding Exercise: Exercises on Transformer Architecture
#Write a Python program to load a pre-trained BERT model from Hugging Face and use it to tokenize a sentence. Use the 'bert-base-uncased' model.

from transformers import BertTokenizer

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

sentence = "Transformers are revolutionizing natural language processing."

tokens = tokenizer.tokenize(sentence)

print("Original Sentence:", sentence)
print("Tokenized Sentence:", tokens)
# Out:
# tokenizer_config.json:   0%|          | 0.00/48.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/570 [00:00<?, ?B/s]
# Original Sentence: Transformers are revolutionizing natural language processing.
# Tokenized Sentence: ['transformers', 'are', 'revolution', '##izing', 'natural', 'language', 'processing', '.']
